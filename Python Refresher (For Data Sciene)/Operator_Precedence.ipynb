# %%
result = 10 + 2 * 3

# %%
result
# Out:
# 16

# %%
54*3/23+4-2**5
# Out:
# -20.956521739130434

# %%
54*3/23+4-32
# Out:
# -20.956521739130434

# %%
162/23+4-32
# Out:
# -20.956521739130434

# %%
7.04+4-32
# Out:
# -20.96

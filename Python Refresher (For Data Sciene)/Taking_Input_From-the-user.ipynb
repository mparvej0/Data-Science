# %%
a = input("Enter the value of a") # By default it takes user input as string

# %%
a
# Out:
# '45'

# %%
b = input("Enter the value of b")

# %%
b
# Out:
# '4'

# %%
a + b
# Out:
# '454'

# %%
int(a) + int(b)
# Out:
# 49

# %%
c = input()

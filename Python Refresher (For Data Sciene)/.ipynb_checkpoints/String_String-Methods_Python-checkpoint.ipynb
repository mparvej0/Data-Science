# %%
name = "Harry"

# %%
name
# Out:
# 'Harry'

# %%
name.upper()
# Out:
# 'HARRY'

# %%
name.endswith("ju")
# Out:
# False

# %%
name.endswith("jery")
# Out:
# False

# %%
name.lower()
# Out:
# 'harry'

# %%
name.count("a")
# Out:
# 1

# %%
name.count("r")
# Out:
# 2

# %%
s = "CodewithHarry"
print(len(s)) # Output: 13
# Out:
# 13

# %%
s[0:5]
# Out:
# 'Codew'

# %%
s[1:-1]
# Out:
# 'odewithHarr'

# %%
s[1:12]
# Out:
# 'odewithHarr'

# %%
s[-12:-1]
# Out:
# 'odewithHarr'

# %%
s[1:12]
# Out:
# 'odewithHarr'

# %%
e = ()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
l = []

# %%
type(l)
# Out:
# list

# %%
t = (5, 64, 23, 23)

# %%
t
# Out:
# (5, 64, 23, 23)

# %%
len(t)
# Out:
# 4

# %%
t[1]
# Out:
# 64

# %%
t[0]
# Out:
# 5

# %%
# Packing
person = ("Alice", 25, "Engineer")

# Unpacking
name, age
